# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
tar = os.chdir("H:\Advance Data Science\Midterm\historical_data1_Q12005")
os.getcwd()
# Out:
# 'H:\\Advance Data Science\\Midterm\\historical_data1_Q12005'

# %%
Quarter_procssed_data = pd.read_table("Quarter2005.csv",sep=',')

# %%
Quarter_procssed_data.head()
# Out:
#    CREDIT_SCORE  FIRST_PAYMENT_DATE FIRST_TIME_HOMEBUYER_FLAG  MATURITY_DATE  \
# 0           699              200505                         N         203504
# 1           691              200504                         N         203503
# 2           713              200503                         N         203502
# 3           719              200505                         N         203504
# 4           656              200503                         N         203502
#
#        MSA  MORTGAGE_INSURANCE_PERCENTAGE_MI  NUMBER_OF_UNITS  \
# 0  39300.0                                 0              1.0
# 1  36420.0                                25              1.0
# 2  28740.0                                 0              1.0
# 3      0.0                                 0              1.0
# 4  40340.0                                 0              1.0
#
#   OCCUPANCY_STATUS  ORIGINAL_COMBINED_LOAN_TO_VALUE_CLTV  \
# 0                O                                  56.0
# ...

# %%
Quarter_procssed_data.describe()
# Out:
#         CREDIT_SCORE  FIRST_PAYMENT_DATE  MATURITY_DATE            MSA  \
# count  351739.000000       351739.000000  351739.000000  351739.000000
# mean      722.108501       200504.721819  203110.734152   25796.126219
# std        60.513949           10.507942     651.172151   15225.950543
# min         0.000000       200001.000000  201002.000000       0.000000
# 25%       682.000000       200503.000000  202504.000000   14860.000000
# 50%       729.000000       200504.000000  203503.000000   28140.000000
# 75%       770.000000       200505.000000  203504.000000   38860.000000
# max       850.000000       201509.000000  205109.000000   49740.000000
#
#        MORTGAGE_INSURANCE_PERCENTAGE_MI  NUMBER_OF_UNITS  \
# count                     351739.000000    351739.000000
# mean                           3.382454         1.029283
# std                            8.954509         0.215616
# min                            0.000000         0.000000
# ...

# %% [markdown]
# ## Plot Data

# %% [markdown]
# ### Plot Credit Score to analyse the range of scores that people may possess in that quarter

# %%
plt.hist(Quarter_procssed_data.CREDIT_SCORE)
# Out:
# (array([  2.12000000e+02,   0.00000000e+00,   0.00000000e+00,
#           5.38000000e+02,   3.00000000e+00,   1.39000000e+02,
#           4.14200000e+03,   7.77180000e+04,   1.68179000e+05,
#           1.00808000e+05]),
#  array([   0.,   85.,  170.,  255.,  340.,  425.,  510.,  595.,  680.,
#          765.,  850.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(Quarter_procssed_data.ORIGINAL_INTEREST_RATE, color='maroon')
# Out:
# (array([  1.70000000e+01,   3.49600000e+03,   1.30263000e+05,
#           1.94700000e+05,   2.23510000e+04,   8.15000000e+02,
#           8.20000000e+01,   9.00000000e+00,   2.00000000e+00,
#           4.00000000e+00]),
#  array([  3.5  ,   4.185,   4.87 ,   5.555,   6.24 ,   6.925,   7.61 ,
#           8.295,   8.98 ,   9.665,  10.35 ]),
#  <a list of 10 Patch objects>)

# %%
# Boxplot for State and Interest rate
data_to_plot = [Quarter_procssed_data.ORIGINAL_INTEREST_RATE]

# %%
Quarter_procssed_data.PROPERTY_STATE.isnull().values.any()
# Out:
# False

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(30, 25))
bp = sns.boxplot(Quarter_procssed_data.PROPERTY_STATE.sort_values(),Quarter_procssed_data.ORIGINAL_INTEREST_RATE)
bp.set_title("Interest Rates across States",fontsize=50)
bp.set_xlabel('') 
bp.set_ylabel('')
yl = bp.set_yticklabels(Quarter_procssed_data.ORIGINAL_INTEREST_RATE,rotation=90,fontsize=30)
xl = bp.set_xticklabels(bp.get_xticklabels(),rotation=90,fontsize=30)
